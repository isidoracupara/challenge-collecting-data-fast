# %%
import pandas as pd
import seaborn as sn

# %%
df = pd.read_csv("../data/clean_properties.tsv", sep='\t')

# %%
df.property_type.unique()
# Out:
# array(['house', 'apartment-block', 'villa', 'mixed-use-building',
#        'mansion', 'town-house', 'bungalow', 'farmhouse',
#        'exceptional-property', 'country-cottage', 'manor-house',
#        'apartment', 'chalet', 'other-property', 'castle', 'penthouse',
#        'service-flat', 'flat-studio', 'duplex', 'triplex', 'ground-floor',
#        'kot', 'loft'], dtype=object)

# %%
df['kitchen type'].unique()
# Out:
# array([nan,  3.,  0.,  1.,  2.])

# %%
df
# Out:
#                                                      url property_type  \
# 0      https://www.immoweb.be/en/classified/house/for...         house
# 1      https://www.immoweb.be/en/classified/house/for...         house
# 2      https://www.immoweb.be/en/classified/house/for...         house
# 3      https://www.immoweb.be/en/classified/house/for...         house
# 4      https://www.immoweb.be/en/classified/house/for...         house
# ...                                                  ...           ...
# 18788  https://www.immoweb.be/en/classified/apartment...     apartment
# 18789  https://www.immoweb.be/en/classified/loft/for-...          loft
# 18790  https://www.immoweb.be/en/classified/apartment...     apartment
# 18791  https://www.immoweb.be/en/classified/duplex/fo...        duplex
# 18792  https://www.immoweb.be/en/classified/apartment...     apartment
#
#                 city     price  bedrooms  online  living area  plot surface  \
# ...
