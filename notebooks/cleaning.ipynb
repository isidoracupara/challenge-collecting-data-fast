# %%
import pandas as pd
import ujson
import numpy as np

# %%
def load_data():
    try:
        with open('../data/temp.json', 'r') as fd:
            print("Loading temp_data.")
            return ujson.load(fd)
    except:
        return dict()
        print("No dump found.")

# %%
json = load_data()
# Out:
# Loading temp_data.

# %%
df = pd.DataFrame(json['existing_properties'])
df = df.set_index('url')
df.price = df.price.str.extract(r'.*[ \n](\d+) €').astype(float)
df['online'] = np.where(df['venue of the sale'] == "link to online sale", True, False)
df['living area'] = df['living area'].str.extract(r'(\d+)').astype(float)
df['plot surface'] = df['surface of the plot'].str.extract(r'(\d+)').astype(float)
df['kitchen type'] = df['kitchen type'].mask(df['kitchen type']=='installed', 1)
df['kitchen type'] = df['kitchen type'].mask(df['kitchen type']=='semi equipped', 2)
df['kitchen type'] = df['kitchen type'].mask(df['kitchen type']=='hyper equipped', 3)
df["terrace surface"] = df["terrace surface"].str.extract(r'(\d+)').astype(float)
df["garden surface"] = df["garden surface"].str.extract(r'(\d+)').astype(float)
df['furnished'] = df['furnished'].mask(df['furnished']=='no', 0)
df['furnished'] = df['furnished'].mask(df['furnished']=='yes', 1)
df['swimming pool'] = df['swimming pool'].mask(df['swimming pool']=='no', 0)
df['swimming pool'] = df['swimming pool'].mask(df['swimming pool']=='yes', 1)



clean_df = df[['city', 'price', 'bedrooms', 'online', 'living area', 'plot surface', 'kitchen type', 'terrace surface', 'furnished', 'garden surface', 'swimming pool', 'number of frontages', 'building condition', 'how many fireplaces?']]

for c in clean_df.columns:
    try:
        clean_df[c].loc[c, :] = clean_df[c].astype(float)
    except:
        pass
# Out:
# /var/folders/9y/tmqxnfps2qz3fzk5fxddx2y80000gn/T/ipykernel_32791/59247840.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead.  To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['online'] = np.where(df['venue of the sale'] == "link to online sale", True, False)
# /var/folders/9y/tmqxnfps2qz3fzk5fxddx2y80000gn/T/ipykernel_32791/59247840.py:6: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead.  To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['plot surface'] = df['surface of the plot'].str.extract(r'(\d+)').astype(float)

# %%
clean_df.to_csv('../data/clean_properties.tsv', sep='\t')

# %%
clean_df
# Out:
#                                                                         city  \
# url
# https://www.immoweb.be/en/classified/house/for-...  Seraing-jemeppesur-meuse
# https://www.immoweb.be/en/classified/house/for-...                    Laarne
# https://www.immoweb.be/en/classified/apartment-...                 Bruxelles
# https://www.immoweb.be/en/classified/villa/for-...                  Glabbeek
# https://www.immoweb.be/en/classified/house/for-...                Anderlecht
# ...                                                                      ...
# https://www.immoweb.be/en/classified/house/for-...                  Stembert
# https://www.immoweb.be/en/classified/house/for-...      Villers-saint-simeon
# https://www.immoweb.be/en/classified/house/for-...                  Soumagne
# https://www.immoweb.be/en/classified/house/for-...                 Vilvoorde
# https://www.immoweb.be/en/classified/house/for-...           Fosses-la-ville
#
#                                                         price  bedrooms  \
# url
# https://www.immoweb.be/en/classified/house/for-...   209500.0       3.0
# https://www.immoweb.be/en/classified/house/for-...   379000.0       3.0
# https://www.immoweb.be/en/classified/apartment-...  3150000.0      12.0
# https://www.immoweb.be/en/classified/villa/for-...   568000.0       4.0
# https://www.immoweb.be/en/classified/house/for-...   289000.0       3.0
# ...                                                       ...       ...
# https://www.immoweb.be/en/classified/house/for-...   199000.0       3.0
# https://www.immoweb.be/en/classified/house/for-...   200000.0       5.0
# https://www.immoweb.be/en/classified/house/for-...   289000.0       4.0
# https://www.immoweb.be/en/classified/house/for-...   195000.0       3.0
# https://www.immoweb.be/en/classified/house/for-...   198000.0       3.0
#
#                                                     online  living area  \
# url
# https://www.immoweb.be/en/classified/house/for-...     0.0         86.0
# https://www.immoweb.be/en/classified/house/for-...     0.0        140.0
# https://www.immoweb.be/en/classified/apartment-...     0.0        980.0
# https://www.immoweb.be/en/classified/villa/for-...     0.0        280.0
# https://www.immoweb.be/en/classified/house/for-...     0.0        225.0
# ...                                                    ...          ...
# https://www.immoweb.be/en/classified/house/for-...     0.0        120.0
# https://www.immoweb.be/en/classified/house/for-...     0.0          NaN
# https://www.immoweb.be/en/classified/house/for-...     0.0        132.0
# https://www.immoweb.be/en/classified/house/for-...     0.0         80.0
# https://www.immoweb.be/en/classified/house/for-...     0.0        188.0
#
#                                                     plot surface kitchen type  \
# url
# https://www.immoweb.be/en/classified/house/for-...          85.0            2
# https://www.immoweb.be/en/classified/house/for-...         215.0          NaN
# https://www.immoweb.be/en/classified/apartment-...         245.0            2
# https://www.immoweb.be/en/classified/villa/for-...        1000.0            1
# https://www.immoweb.be/en/classified/house/for-...         195.0            2
# ...                                                          ...          ...
# https://www.immoweb.be/en/classified/house/for-...         104.0            1
# https://www.immoweb.be/en/classified/house/for-...           NaN          NaN
# https://www.immoweb.be/en/classified/house/for-...         700.0            1
# https://www.immoweb.be/en/classified/house/for-...          95.0          NaN
# https://www.immoweb.be/en/classified/house/for-...         191.0            2
#
#                                                     terrace surface  \
# url
# https://www.immoweb.be/en/classified/house/for-...             17.0
# https://www.immoweb.be/en/classified/house/for-...             20.0
# https://www.immoweb.be/en/classified/apartment-...             30.0
# https://www.immoweb.be/en/classified/villa/for-...             65.0
# https://www.immoweb.be/en/classified/house/for-...              NaN
# ...                                                             ...
# https://www.immoweb.be/en/classified/house/for-...              NaN
# https://www.immoweb.be/en/classified/house/for-...              NaN
# https://www.immoweb.be/en/classified/house/for-...             60.0
# https://www.immoweb.be/en/classified/house/for-...              NaN
# https://www.immoweb.be/en/classified/house/for-...              NaN
#
#                                                     furnished  garden surface  \
# url
# https://www.immoweb.be/en/classified/house/for-...        0.0            20.0
# https://www.immoweb.be/en/classified/house/for-...        0.0           130.0
# https://www.immoweb.be/en/classified/apartment-...        0.0             NaN
# https://www.immoweb.be/en/classified/villa/for-...        0.0           600.0
# https://www.immoweb.be/en/classified/house/for-...        NaN             NaN
# ...                                                       ...             ...
# https://www.immoweb.be/en/classified/house/for-...        NaN             NaN
# https://www.immoweb.be/en/classified/house/for-...        NaN             NaN
# https://www.immoweb.be/en/classified/house/for-...        0.0           500.0
# https://www.immoweb.be/en/classified/house/for-...        0.0             NaN
# https://www.immoweb.be/en/classified/house/for-...        0.0             NaN
#
#                                                     swimming pool  \
# url
# https://www.immoweb.be/en/classified/house/for-...            0.0
# https://www.immoweb.be/en/classified/house/for-...            0.0
# https://www.immoweb.be/en/classified/apartment-...            0.0
# https://www.immoweb.be/en/classified/villa/for-...            0.0
# https://www.immoweb.be/en/classified/house/for-...            0.0
# ...                                                           ...
# https://www.immoweb.be/en/classified/house/for-...            NaN
# https://www.immoweb.be/en/classified/house/for-...            NaN
# https://www.immoweb.be/en/classified/house/for-...            0.0
# https://www.immoweb.be/en/classified/house/for-...            NaN
# https://www.immoweb.be/en/classified/house/for-...            NaN
#
#                                                     number of frontages  \
# url
# https://www.immoweb.be/en/classified/house/for-...                  2.0
# https://www.immoweb.be/en/classified/house/for-...                  2.0
# https://www.immoweb.be/en/classified/apartment-...                  2.0
# https://www.immoweb.be/en/classified/villa/for-...                  4.0
# https://www.immoweb.be/en/classified/house/for-...                  2.0
# ...                                                                 ...
# https://www.immoweb.be/en/classified/house/for-...                  3.0
# https://www.immoweb.be/en/classified/house/for-...                  NaN
# https://www.immoweb.be/en/classified/house/for-...                  4.0
# https://www.immoweb.be/en/classified/house/for-...                  2.0
# https://www.immoweb.be/en/classified/house/for-...                  2.0
#
#                                                    building condition  \
# url
# https://www.immoweb.be/en/classified/house/for-...             as new
# https://www.immoweb.be/en/classified/house/for-...             as new
# https://www.immoweb.be/en/classified/apartment-...        to renovate
# https://www.immoweb.be/en/classified/villa/for-...             as new
# https://www.immoweb.be/en/classified/house/for-...      to be done up
# ...                                                               ...
# https://www.immoweb.be/en/classified/house/for-...                NaN
# https://www.immoweb.be/en/classified/house/for-...                NaN
# https://www.immoweb.be/en/classified/house/for-...               good
# https://www.immoweb.be/en/classified/house/for-...                NaN
# https://www.immoweb.be/en/classified/house/for-...                NaN
#
#                                                     how many fireplaces?
# url
# https://www.immoweb.be/en/classified/house/for-...                   NaN
# https://www.immoweb.be/en/classified/house/for-...                   NaN
# https://www.immoweb.be/en/classified/apartment-...                   NaN
# https://www.immoweb.be/en/classified/villa/for-...                   1.0
# https://www.immoweb.be/en/classified/house/for-...                   NaN
# ...                                                                  ...
# https://www.immoweb.be/en/classified/house/for-...                   NaN
# https://www.immoweb.be/en/classified/house/for-...                   NaN
# https://www.immoweb.be/en/classified/house/for-...                   NaN
# https://www.immoweb.be/en/classified/house/for-...                   NaN
# https://www.immoweb.be/en/classified/house/for-...                   NaN
#
# [90 rows x 14 columns]

# %%
for c in df.columns:
    if 'fire' in c:
        print("@%s@" %c)
# Out:
# @how many fireplaces?@

# %%
set(df['building condition'])
# Out:
# {'as new', 'good', 'just renovated', nan, 'to be done up', 'to renovate'}

# %%
df['kitchen type'] == "installed"
# Out:
# url
# https://www.immoweb.be/en/classified/house/for-sale/seraing-jemeppesur-meuse/4101/9706383    False
# https://www.immoweb.be/en/classified/house/for-sale/laarne/9270/9706369                      False
# https://www.immoweb.be/en/classified/apartment-block/for-sale/bruxelles/1000/9706352         False
# https://www.immoweb.be/en/classified/villa/for-sale/glabbeek/3380/9706364                     True
# https://www.immoweb.be/en/classified/house/for-sale/anderlecht/1070/9706402                  False
# https://www.immoweb.be/en/classified/house/for-sale/boechout/2530/9706389                     True
# https://www.immoweb.be/en/classified/house/for-sale/gent/9000/9706397                         True
# https://www.immoweb.be/en/classified/villa/for-sale/anhee/5537/9706381                       False
# https://www.immoweb.be/en/classified/house/for-sale/huldenberg/3040/9706406                  False
# https://www.immoweb.be/en/classified/house/for-sale/lembeek/1502/9706346                     False
# https://www.immoweb.be/en/classified/house/for-sale/tremelo/3120/9706361                     False
# https://www.immoweb.be/en/classified/mixed-use-building/for-sale/gooik/1755/9706365          False
# https://www.immoweb.be/en/classified/house/for-sale/maldegem/9990/9706388                     True
# https://www.immoweb.be/en/classified/house/for-sale/marchienne-au-pont/6030/9706349          False
# https://www.immoweb.be/en/classified/villa/for-sale/oostduinkerke/8670/9706415               False
# https://www.immoweb.be/en/classified/house/for-sale/genappe/1470/9706357                     False
# https://www.immoweb.be/en/classified/house/for-sale/sint-maria-horebeke/9667/9706377         False
# https://www.immoweb.be/en/classified/house/for-sale/boechout/2530/9706373                    False
# https://www.immoweb.be/en/classified/house/for-sale/chatelet-chatelineau/6200/9706359         True
# https://www.immoweb.be/en/classified/house/for-sale/la-hestre/7170/9706355                    True
# https://www.immoweb.be/en/classified/country-cottage/for-sale/gooik/1755/9706366             False
# https://www.immoweb.be/en/classified/house/for-sale/meux/5081/9706363                        False
# https://www.immoweb.be/en/classified/house/for-sale/jambes/5100/9706398                       True
# https://www.immoweb.be/en/classified/house/for-sale/sint-michiels/8200/9706385               False
# https://www.immoweb.be/en/classified/house/for-sale/hastiere/5540/9706419                     True
# https://www.immoweb.be/en/classified/house/for-sale/izegem/8870/9706390                      False
# https://www.immoweb.be/en/classified/house/for-sale/saint-aubin/5620/9706395                 False
# https://www.immoweb.be/en/classified/house/for-sale/dinant/5501/9706418                      False
# https://www.immoweb.be/en/classified/bungalow/for-sale/bomal/1367/9706408                    False
# https://www.immoweb.be/en/classified/house/for-sale/forest/1190/9689361                       True
# Name: kitchen type, dtype: bool

# %%
df.iloc[-2].price

# %%
df.shape
# Out:
# (90, 106)
